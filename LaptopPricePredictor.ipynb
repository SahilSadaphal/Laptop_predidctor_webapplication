# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.shape
# Out:
# (1303, 11)

# %%
df.info()

'''
Ram needs to be converted in int
Weight needs to be converted in float
'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB
# '\nRam needs to be converted in int\nWeight needs to be converted in float\n'

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# # ***Handling Duplicated Values***

# %%
df.duplicated()
'''Duplicated values needed to be removed'''
# Out:
# 'Duplicated values needed to be removed'

# %%
dup_index=df[df.duplicated()].index

# %%
df.drop([1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284,
            1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295,
            1296, 1297, 1298, 1299, 1300, 1301, 1302],inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # ***PreProcessing***

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz  8GB  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price
# 0  1.37kg  71378.6832

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df['Ram']=df['Ram'].astype(int)
df['Weight']=df['Weight'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int64
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float64
#  10  Price             1274 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 109.6+ KB

# %% [markdown]
# # ***EDA***

# %%
import seaborn as sns

# %%
df.head(3)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight       Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232
# 2         Intel HD Graphics 620  No OS    1.86  30636.0000

# %%
sns.histplot(df['Price'],kde=True)
'''
We can see that price is skewed that is there are more laptops in low price range and less laptops in more price range

'''
# Out:
# '\nWe can see that price is skewed that is there are more laptops in low price range and less laptops in more price range\n\n'

# %%
df['Company'].value_counts().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

'''We can see that clearly that brand [company] influences price a lot'''
# Out:
# 'We can see that clearly that brand [company] influences price a lot'

# %%
df['TypeName'].value_counts().plot(kind='bar')
'''
Notebook---laptops for officework
Gaming---laptops for gaming
Ultrabook---laptops for resource extensive tasks(editing,etc)
2 in 1 convertible---convertible laptops in tab
Workstation---heavy duty laptop
netbook---less price laptops
'''
# Out:
# '\nNotebook---laptops for officework\nGaming---laptops for gaming\nUltrabook---laptops for resource extensive tasks(editing,etc)\n2 in 1 convertible---convertible laptops in tab \nWorkstation---heavy duty laptop\nnetbook---less price laptops \n'

# %%
#Checking avg value of every type
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

'''
We can see that avg price of workstation is high,then followed by gaming and so on
This means types of laptop influences target variable price
'''
# Out:
# '\nWe can see that avg price of workstation is high,then followed by gaming and so on\nThis means types of laptop influences target variable price \n'

# %%
sns.displot(df['Inches'],kde=True)

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
'''
There is somewhat correlation between inches and price
'''
# Out:
# '\nThere is somewhat correlation between inches and price\n'

# %%
df['ScreenResolution'].value_counts()
'''
There is hidden information in ScreenResolution col
like
1)is laptop hd
2)ips panel available
3)resolution
'''
# Out:
# '\nThere is hidden information in ScreenResolution col\nlike \n1)is laptop hd\n2)ips panel available\n3)resolution\n'

# %%
#FEATURE ENGINEERING

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(3)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 657     Dell  Notebook    15.6            Full HD 1920x1080
# 539   Lenovo  Notebook    14.0  IPS Panel Full HD 1920x1080
# 1085      HP  Notebook    14.0            Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 657   Intel Core i7 8550U 1.8GHz   16  256GB SSD +  2TB HDD
# 539   Intel Core i7 7500U 2.7GHz    8             256GB SSD
# 1085  Intel Core i5 6200U 2.3GHz    4             500GB HDD
#
#                         Gpu       OpSys  Weight       Price  Touchscreen
# 657          AMD Radeon 530  Windows 10    2.20  60472.8000            0
# 539    Nvidia GeForce 940MX  Windows 10    1.87  45767.5200            0
# 1085  Intel HD Graphics 520   Windows 7    1.54  54931.1472            0

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
'''
Touchscreen laptops have higher avg price in general
We can use this col for target prediction
'''
# Out:
# '\nTouchscreen laptops have higher avg price in general\nWe can use this col for target prediction\n'

# %%
df['IPS_Panel']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df.sample(2)
# Out:
#      Company            TypeName  Inches                 ScreenResolution  \
# 1044      HP            Notebook    14.0                Full HD 1920x1080
# 50    Lenovo  2 in 1 Convertible    10.1  IPS Panel Touchscreen 1920x1200
#
#                               Cpu  Ram              Memory  \
# 1044   Intel Core i5 6200U 2.3GHz    4           500GB HDD
# 50    Intel Atom x5-Z8550 1.44GHz    4  64GB Flash Storage
#
#                         Gpu       OpSys  Weight     Price  Touchscreen  \
# 1044  Intel HD Graphics 520  Windows 10    1.54  53280.00            0
# 50    Intel HD Graphics 400     Android    0.69  16996.32            1
#
#       IPS_Panel
# 1044          0
# 50            1

# %%
df['IPS_Panel'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['IPS_Panel'],y=df['Price'])
'''
Ips display on avg have higher price
'''
# Out:
# '\nIps display on avg have higher price\n'

# %%
# Extracting Resolution

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)
df['x_res']=new[0]
df['y_res']=new[1]
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df['x_res'] = df['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df['x_res']=df['x_res'].astype('int')
df['y_res']=df['y_res'].astype('int')

# %%
df.corr()['Price']
# Out:
# <ipython-input-162-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188631
# IPS_Panel      0.250358
# x_res          0.552074
# y_res          0.548111
# Name: Price, dtype: float64

# %%
'''
There is high correlation between x_res and price y_res and price
So we can say your feature engineering for screenresolution column is quite sucessfull
'''
# Out:
# '\nThere is high correlation between x_res and price y_res and price\nSo we can say your feature engineering for screenresolution column is quite sucessfull\n'

# %%
'''
Creating a new column from x,y_res column
PPI
'''
df['ppi']=((df['x_res']**2)+(df['y_res']**2))**0.5/(df['Inches']).astype('float')

# %%
df.head(3)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86  30636.0000            0
#
#    IPS_Panel  x_res  y_res         ppi
# 0          1   2560   1600  226.983005
# 1          0   1440    900  127.677940
# 2          0   1920   1080  141.211998

# %%
df.corr()['Price']
# Out:
# <ipython-input-166-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188631
# IPS_Panel      0.250358
# x_res          0.552074
# y_res          0.548111
# ppi            0.469539
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution','Inches','x_res','y_res'],inplace=True)

# %%
df.head(3)
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86  30636.0000            0
#
#    IPS_Panel         ppi
# 0          1  226.983005
# 1          0  127.677940
# 2          0  141.211998

# %%
#CPU COLUMN

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     190
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     132
# Intel Core i7 8550U 1.8GHz      73
# Intel Core i5 8250U 1.6GHz      72
#                               ...
# Intel Core M M3-6Y30 0.9GHz      1
# AMD A9-Series 9420 2.9GHz        1
# Intel Core i5 2.9GHz             1
# AMD A6-Series 7310 2GHz          1
# AMD A9-Series 9410 2.9GHz        1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['cpu name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
#Fetching 1st 3 name from cpy colums

# %%
df.head(2)
# Out:
#   Company   TypeName                   Cpu  Ram               Memory  \
# 0   Apple  Ultrabook  Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0
#
#    IPS_Panel         ppi       cpu name
# 0          1  226.983005  Intel Core i5
# 1          0  127.677940  Intel Core i5

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['cpu brand']=df['cpu name'].apply(fetch_processor)

# %%
df.head(19)
# Out:
#    Company   TypeName                         Cpu  Ram               Memory  \
# 0    Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1    Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2       HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3    Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4    Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
# 5     Acer   Notebook     AMD A9-Series 9420 3GHz    4            500GB HDD
# 6    Apple  Ultrabook        Intel Core i7 2.2GHz   16  256GB Flash Storage
# 7    Apple  Ultrabook        Intel Core i5 1.8GHz    8  256GB Flash Storage
# 8     Asus  Ultrabook  Intel Core i7 8550U 1.8GHz   16            512GB SSD
# 9     Acer  Ultrabook  Intel Core i5 8250U 1.6GHz    8            256GB SSD
# 10      HP   Notebook  Intel Core i5 7200U 2.5GHz    4            500GB HDD
# ...

# %%
df['cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head(1)
# Out:
#   Company   TypeName                   Cpu  Ram     Memory  \
# 0   Apple  Ultrabook  Intel Core i5 2.3GHz    8  128GB SSD
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0
#
#    IPS_Panel         ppi       cpu name      cpu brand
# 0          1  226.983005  Intel Core i5  Intel Core i5

# %%
df.drop(columns=['Cpu','cpu name'],inplace=True)

# %%
#RAM

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
df.corr()['Price']
# Out:
# <ipython-input-183-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188631
# IPS_Panel      0.250358
# ppi            0.469539
# Name: Price, dtype: float64

# %%
#Memory

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          215
# 500GB HDD                        123
# 512GB SSD                        114
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                36
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                13
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 1.0TB Hybrid                       7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df.sample(10)
# Out:
#      Company            TypeName  Ram              Memory  \
# 1014      HP            Notebook    4           500GB HDD
# 442   Lenovo           Ultrabook    8           256GB SSD
# 456     Dell            Notebook    8             1TB HDD
# 1170      HP            Notebook    8           256GB SSD
# 16      Dell            Notebook    8           256GB SSD
# 462     Asus            Notebook    8             1TB HDD
# 353       HP         Workstation    8           256GB SSD
# 1126  Lenovo  2 in 1 Convertible    4  64GB Flash Storage
# 278   Lenovo            Notebook    4             1TB HDD
# 736       HP         Workstation   16           256GB SSD
#
#                           Gpu       OpSys  Weight        Price  Touchscreen  \
# 1014    Intel HD Graphics 620  Windows 10    1.49   42624.0000            0
# 442     Intel HD Graphics 620  Windows 10    1.36   76137.1200            0
# 456   Nvidia GeForce GTX 1060  Windows 10    4.42  109010.8800            0
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)
df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# <ipython-input-187-0263bfd59582>:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# <ipython-input-187-0263bfd59582>:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
pd.set_option('display.max_columns',None) #To see all values
df.sample(10)
# Out:
#       Company   TypeName  Ram               Memory                      Gpu  \
# 648   Toshiba   Notebook    8              256 SSD    Intel HD Graphics 520
# 373    Lenovo   Notebook    4              128 SSD            AMD Radeon R5
# 385    Lenovo  Ultrabook    8              512 SSD    Intel HD Graphics 620
# 1120     Vero   Notebook    4     32 Flash Storage    Intel HD Graphics 400
# 394      Dell   Notebook    8              256 SSD       AMD Radeon R7 M445
# 150      Dell     Gaming   16              512 SSD  Nvidia GeForce GTX 1050
# 1197     Asus     Gaming   16  512 SSD +  1000 HDD  Nvidia GeForce GTX 980M
# 376    Lenovo    Netbook    4              128 SSD    Intel HD Graphics 500
# 943   Toshiba   Notebook    8              256 SSD    Intel HD Graphics 520
# 647     Razer     Gaming   16              256 SSD  Nvidia GeForce GTX 1060
#
#            OpSys  Weight        Price  Touchscreen  IPS_Panel         ppi  \
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head(3)
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
#
#         Price  Touchscreen  IPS_Panel         ppi      cpu brand  HDD  SSD  \
# 0  71378.6832            0          1  226.983005  Intel Core i5    0  128
# 1  47895.5232            0          0  127.677940  Intel Core i5    0    0
# 2  30636.0000            0          0  141.211998  Intel Core i5    0  256
#
#    Hybrid  Flash_Storage
# 0       0              0
# 1       0            128
# 2       0              0

# %%
df.corr()['Price']
# Out:
# <ipython-input-191-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Ram              0.740106
# Weight           0.212192
# Price            1.000000
# Touchscreen      0.188631
# IPS_Panel        0.250358
# ppi              0.469539
# HDD             -0.098011
# SSD              0.669957
# Hybrid           0.022533
# Flash_Storage   -0.037176
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      279
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     703
# Nvidia    396
# AMD       174
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     703
# Nvidia    396
# AMD       174
# Name: Gpu brand, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS_Panel  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0          1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0          0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0          0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0          1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0          1
#
#           ppi      cpu brand  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1047
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS_Panel  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0          1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0          0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0          0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0          1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0          1
#
#           ppi      cpu brand  HDD  SSD Gpu brand                  os
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# <ipython-input-208-05ee4c8848be>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.corr()['Price']
# Out:
# <ipython-input-210-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Ram            0.739996
# Weight         0.211667
# Price          1.000000
# Touchscreen    0.190382
# IPS_Panel      0.251514
# ppi            0.471481
# HDD           -0.098481
# SSD            0.669808
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-211-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.distplot(np.log(df['Price']))
#creating normal distribution for weight for model performance
# Out:
# <ipython-input-212-e76713b4b020>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS_Panel  \
# 0      Apple           Ultrabook    8    1.37            0          1
# 1      Apple           Ultrabook    8    1.34            0          0
# 2         HP            Notebook    8    1.86            0          0
# 3      Apple           Ultrabook   16    1.83            0          1
# 4      Apple           Ultrabook    8    1.37            0          1
# ...      ...                 ...  ...     ...          ...        ...
# 1269    Asus            Notebook    4    2.20            0          0
# 1270  Lenovo  2 in 1 Convertible    4    1.80            1          1
# 1271  Lenovo  2 in 1 Convertible   16    1.30            1          1
# 1272  Lenovo            Notebook    2    1.50            0          0
# 1273      HP            Notebook    6    2.19            0          0
#
#              ppi              cpu brand   HDD  SSD Gpu brand  \
# 0     226.983005          Intel Core i5     0  128     Intel
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1269    10.555257
# 1270    10.433899
# 1271    11.288115
# 1272     9.409283
# 1273    10.614129
# Name: Price, Length: 1273, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7831567119403513
# MAE 0.22167696450805457
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram  Weight       Price  Touchscreen  IPS_Panel  \
# 0   Apple  Ultrabook    8    1.37  71378.6832            0          1
#
#           ppi      cpu brand  HDD  SSD Gpu brand   os
# 0  226.983005  Intel Core i5    0  128     Intel  Mac

# %% [markdown]
# # ***RidgeRegression***

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7954034365506929
# MAE 0.2181888477223964
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # ***Lasso***

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7930860259205395
# MAE 0.21874223214615685
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # ***KNeighborsRegressor***

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.7468183864531253
# MAE 0.2153347210269153

# %% [markdown]
# # ***DecisionTreeRegressor***

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8063762191552084
# MAE 0.20672120419859485
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # ***SVM***

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8239727290040478
# MAE 0.20196514797543924

# %% [markdown]
# # ***RandomForestRegressor***

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8497764509753524
# MAE 0.18072585460593074

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
X_train
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS_Panel  \
# 716     Dell            Notebook    8    1.90            0          0
# 21    Lenovo              Gaming    8    2.50            0          1
# 968     Dell              Gaming   32    4.42            0          1
# 273   Lenovo  2 in 1 Convertible   16    1.36            1          0
# 1234   Apple           Ultrabook    4    1.08            0          0
# ...      ...                 ...  ...     ...          ...        ...
# 466     Acer            Notebook    4    2.20            0          0
# 299     Asus           Ultrabook   16    1.63            0          0
# 493     Acer            Notebook    8    2.20            0          0
# 527   Lenovo            Notebook    8    2.20            0          0
# 1193   Apple           Ultrabook    8    0.92            0          1
#
#              ppi              cpu brand   HDD  SSD Gpu brand  \
# 716   141.211998          Intel Core i5     0  256     Intel
# ...
